# %% [markdown]
# # 02 — Data Profiling

# %%
from pathlib import Path
import sys, pandas as pd
ROOT=Path.cwd().parent
if str(ROOT) not in sys.path: sys.path.insert(0,str(ROOT))
DATA=ROOT/'data'/'uploads'/'sample_business_data.csv'
df=pd.read_csv(DATA)
df.head()

from src.analysis.core import profile,quality_score
summary,columns=profile(df)
print(summary)
print('Quality score:',quality_score(df))
columns
# Out:
# {'rows': 500, 'columns': 7, 'duplicates': 0, 'memory_mb': np.float64(0.049), 'numeric': 6, 'categorical': 1}
# Quality score: 100.0
#          column    dtype  non_null  missing  missing_pct  unique
# 0   customer_id    int64       500        0          0.0     500
# 1           age    int64       500        0          0.0      53
# 2        income    int64       500        0          0.0     499
# 3        region   object       500        0          0.0       4
# 4        visits    int64       500        0          0.0      20
# 5  satisfaction  float64       500        0          0.0      41
# 6     purchased    int64       500        0          0.0       2
